# %%
# !pip install opencv-contrib-python==3.4.2.16
import cv2 
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#reading image
img1 = cv2.imread('/content/drive/My Drive/Colab Notebooks/faces/AnyConv.com__1.jpg')  
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

#keypoints
sift = cv2.xfeatures2d.SIFT_create()
keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)

img_1 = cv2.drawKeypoints(gray1,keypoints_1,img1)
plt.imshow(img_1)

# %%
img1 = cv2.imread('/content/drive/My Drive/Colab Notebooks/faces/AnyConv.com__1.jpg')
img2 = cv2.imread('/content/drive/My Drive/Colab Notebooks/faces/AnyConv.com__2.jpg') 

img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

figure, (ax1,ax2) = plt.subplots(1, 2, figsize=(16, 8))
ax1.imshow(img1, cmap='gray')
ax2.imshow(img2, cmap='gray')

# %%
keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
keypoints_2, descriptors_2 = sift.detectAndCompute(img2,None)

len(keypoints_1), len(keypoints_2)
# Out:
# (57, 76)

# %%
bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:100], img2, flags=2)
plt.imshow(img3),plt.show()
len(matches)
# Out:
# 31

# %%
img4 = cv2.imread('/content/drive/My Drive/Colab Notebooks/faces/AnyConv.com__2 (1).jpg')
img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
keypoints_4, descriptors_4 = sift.detectAndCompute(img4,None)
matches = bf.match(descriptors_1,descriptors_4)
matches = sorted(matches, key = lambda x:x.distance)

img5 = cv2.drawMatches(img1, keypoints_1, img4, keypoints_4, matches[:100], img4, flags=2)
plt.imshow(img5),plt.show()
len(matches)
# Out:
# 29

# %%
img6 = cv2.imread('/content/drive/My Drive/Colab Notebooks/faces/img.jpg')
img6 = cv2.cvtColor(img6, cv2.COLOR_BGR2GRAY)
keypoints_6, descriptors_6 = sift.detectAndCompute(img6,None)
matches = bf.match(descriptors_1,descriptors_6)
matches = sorted(matches, key = lambda x:x.distance)

img7 = cv2.drawMatches(img1, keypoints_1, img6, keypoints_6, matches[:100], img6, flags=2)
plt.imshow(img7),plt.show()
len(matches)
# Out:
# 26
